# %%
import pandas as pd
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport

# %%
#import data
df = pd.read_csv('cfb_dataset_key_variables.csv')

# %%
profile_report = ProfileReport(df)
profile_report.to_file(output_file=f'CFB ProfilingReport')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\Alan\anaconda3\lib\site-packages\ydata_profiling\profile_report.py:360: UserWarning: Extension  not supported. For now we assume .html was intended. To remove this warning, please use .html or .json.
#   warnings.warn(
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df2 = pd.read_csv('cfb_dataset.csv')

# %%
Win = df2["Win"]

# %%
df['Win'] = Win

# %%
df
# Out:
#       Opponent 3rd Percent  Opp Pass TDs Allowed  Yards/Pass Attempt Allowed  \
# 0                    0.279                    10                        7.11
# 1                    0.352                    22                        8.24
# 2                    0.305                    12                        5.63
# 3                    0.423                    18                        7.24
# 4                    0.478                    25                        7.74
# ...                    ...                   ...                         ...
# 1226                 0.381                    23                        7.67
# 1227                 0.427                    24                        7.88
# 1228                 0.451                    10                        6.84
# 1229                 0.457                    16                        6.61
# 1230                 0.306                    16                        6.20
#
#       Pass Yards Per Game Allowed  Opp Redzone Scores  Yds/Rush Allowed  \
# 0                           159.1                  21              3.39
# 1                           243.8                  45              4.26
# 2                           187.8                  33              3.64
# 3                           219.7                  29              3.64
# 4                           258.6                  50              5.59
# ...                           ...                 ...               ...
# 1226                        270.8                  41              4.45
# 1227                        263.3                  50              4.43
# 1228                        177.9                  37              4.29
# 1229                        169.2                  43              5.38
# 1230                        202.5                  25              3.22
#
#       Opp Rush Touchdowns Allowed  Average Sacks per Game  \
# 0                              10                    0.92
# 1                              25                    4.58
# 2                              15                    1.69
# 3                              20                    1.50
# 4                              33                    1.92
# ...                           ...                     ...
# 1226                           25                    2.46
# 1227                           23                    2.33
# 1228                           24                    1.67
# 1229                           30                    1.83
# 1230                            8                    1.23
#
#       Opponents Intercepted  Wins  Opp.Redzone.Scores  Opp.Pass.TDs.Allowed  \
# 0                         9    10                43.0                  27.0
# 1                         9     2                17.0                  13.0
# 2                         7    11                34.0                  20.0
# 3                         7     6                40.0                  24.0
# 4                         3     5                37.0                  25.0
# ...                     ...   ...                 ...                   ...
# 1226                     16     6                41.0                   0.0
# 1227                     12     4                68.0                   0.0
# 1228                     14     8                44.0                   0.0
# 1229                      8     1                34.0                   0.0
# 1230                      9     9                29.0                   1.0
#
#          Win
# 0          5
# 1         11
# 2          8
# 3         10
# 4          3
# ...      ...
# 1226   8-Apr
# 1227  11-Jan
# 1228  11-Jan
# 1229   5-Aug
# 1230  10-Feb
#
# [1231 rows x 13 columns]

# %%
df
# Out:
#                       Opp Pass TDs Allowed  Yards/Pass Attempt Allowed  \
# Opponent 3rd Percent
# 0.279                                   10                        7.11
# 0.352                                   22                        8.24
# 0.305                                   12                        5.63
# 0.423                                   18                        7.24
# 0.478                                   25                        7.74
# ...                                    ...                         ...
# 0.381                                   23                        7.67
# 0.427                                   24                        7.88
# 0.451                                   10                        6.84
# 0.457                                   16                        6.61
# 0.306                                   16                        6.20
#
#                       Pass Yards Per Game Allowed  Opp Redzone Scores  \
# Opponent 3rd Percent
# 0.279                                       159.1                  21
# 0.352                                       243.8                  45
# 0.305                                       187.8                  33
# 0.423                                       219.7                  29
# 0.478                                       258.6                  50
# ...                                           ...                 ...
# 0.381                                       270.8                  41
# 0.427                                       263.3                  50
# 0.451                                       177.9                  37
# 0.457                                       169.2                  43
# 0.306                                       202.5                  25
#
#                       Yds/Rush Allowed  Opp Rush Touchdowns Allowed  \
# Opponent 3rd Percent
# 0.279                             3.39                           10
# 0.352                             4.26                           25
# 0.305                             3.64                           15
# 0.423                             3.64                           20
# 0.478                             5.59                           33
# ...                                ...                          ...
# 0.381                             4.45                           25
# 0.427                             4.43                           23
# 0.451                             4.29                           24
# 0.457                             5.38                           30
# 0.306                             3.22                            8
#
#                       Average Sacks per Game  Opponents Intercepted  Wins  \
# Opponent 3rd Percent
# 0.279                                   0.92                      9    10
# 0.352                                   4.58                      9     2
# 0.305                                   1.69                      7    11
# 0.423                                   1.50                      7     6
# 0.478                                   1.92                      3     5
# ...                                      ...                    ...   ...
# 0.381                                   2.46                     16     6
# 0.427                                   2.33                     12     4
# 0.451                                   1.67                     14     8
# 0.457                                   1.83                      8     1
# 0.306                                   1.23                      9     9
#
#                       Opp.Redzone.Scores  Opp.Pass.TDs.Allowed
# Opponent 3rd Percent
# 0.279                               43.0                  27.0
# 0.352                               17.0                  13.0
# 0.305                               34.0                  20.0
# 0.423                               40.0                  24.0
# 0.478                               37.0                  25.0
# ...                                  ...                   ...
# 0.381                               41.0                   0.0
# 0.427                               68.0                   0.0
# 0.451                               44.0                   0.0
# 0.457                               34.0                   0.0
# 0.306                               29.0                   1.0
#
# [1231 rows x 11 columns]
